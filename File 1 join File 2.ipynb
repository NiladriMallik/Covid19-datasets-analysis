# %%
import pandas as pd
import numpy as np

# %%
output_path = 'OUTPUT DATAFRAME EXCEL SHEETS'
df_india_null_filled_path = output_path + '/df_india_null_filled.xlsx'
df_india_null_filled = pd.read_excel(df_india_null_filled_path)
df_india_null_filled
# Out:
#        Unnamed: 0    Sno        Date     Time          State  \
# 0               0      1  2020-01-30  6:00 PM         Kerala
# 1               1      2  2020-01-31  6:00 PM         Kerala
# 2               2      3  2020-02-01  6:00 PM         Kerala
# 3               3      4  2020-02-02  6:00 PM         Kerala
# 4               4      5  2020-02-03  6:00 PM         Kerala
# ...           ...    ...         ...      ...            ...
# 14973       14973  14974  2021-05-16  8:00 AM      Telangana
# 14974       14974  14975  2021-05-16  8:00 AM        Tripura
# 14975       14975  14976  2021-05-16  8:00 AM    Uttarakhand
# 14976       14976  14977  2021-05-16  8:00 AM  Uttar Pradesh
# 14977       14977  14978  2021-05-16  8:00 AM    West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# ...

# %%
covid_vaccine_statewise = 'covid_vaccine_statewise.csv'
df_covid_vaccine_statewise = pd.read_csv(covid_vaccine_statewise)
df_covid_vaccine_statewise
# Out:
#                                        STATE  FIRST_DOSE_ADMINISTERED  \
# 0                                Maharashtra                634056063
# 1                                  Rajasthan                540692573
# 2                              Uttar Pradesh                521685072
# 3                                    Gujarat                508700924
# 4                                West Bengal                445383722
# 5                                  Karnataka                375603538
# 6                             Madhya Pradesh                342799240
# 7                                     Kerala                296140652
# 8                                      Bihar                282983123
# 9                             Andhra Pradesh                240298705
# 10                                    Odisha                236771496
# 11                                Tamil Nadu                233728503
# ...

# %%
df_cmbnd1_2_inner_temp = pd.merge(df_india_null_filled, df_covid_vaccine_statewise, 
                             how = 'inner', left_on = 'State', right_on = 'STATE',
                            suffixes = ('_left','_right'))
df_cmbnd1_2_inner_temp.head()
# Out:
#    Unnamed: 0  Sno        Date     Time   State ConfirmedIndianNational  \
# 0           0    1  2020-01-30  6:00 PM  Kerala                       1
# 1           1    2  2020-01-31  6:00 PM  Kerala                       1
# 2           2    3  2020-02-01  6:00 PM  Kerala                       2
# 3           3    4  2020-02-02  6:00 PM  Kerala                       3
# 4           4    5  2020-02-03  6:00 PM  Kerala                       3
#
#   ConfirmedForeignNational  Cured  Deaths  Confirmed   STATE  \
# 0                        0      0       0          1  Kerala
# 1                        0      0       0          1  Kerala
# 2                        0      0       0          2  Kerala
# 3                        0      0       0          3  Kerala
# 4                        0      0       0          3  Kerala
#
#    FIRST_DOSE_ADMINISTERED  SECOND_DOSE_ADMINISTERED  ONLY_FIRST_DOSE
# 0                296140652                  56636504        239504148
# ...

# %%
df_cmbnd1_2_inner_temp.columns
# Out:
# Index(['Unnamed: 0', 'Sno', 'Date', 'Time', 'State', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths', 'Confirmed', 'STATE',
#        'FIRST_DOSE_ADMINISTERED', 'SECOND_DOSE_ADMINISTERED',
#        'ONLY_FIRST_DOSE'],
#       dtype='object')

# %%
df_cmbnd1_2_inner_temp.drop('Unnamed: 0',axis = 1, inplace = True)
df_cmbnd1_2_inner_temp.head()
# Out:
#    Sno        Date     Time   State ConfirmedIndianNational  \
# 0    1  2020-01-30  6:00 PM  Kerala                       1
# 1    2  2020-01-31  6:00 PM  Kerala                       1
# 2    3  2020-02-01  6:00 PM  Kerala                       2
# 3    4  2020-02-02  6:00 PM  Kerala                       3
# 4    5  2020-02-03  6:00 PM  Kerala                       3
#
#   ConfirmedForeignNational  Cured  Deaths  Confirmed   STATE  \
# 0                        0      0       0          1  Kerala
# 1                        0      0       0          1  Kerala
# 2                        0      0       0          2  Kerala
# 3                        0      0       0          3  Kerala
# 4                        0      0       0          3  Kerala
#
#    FIRST_DOSE_ADMINISTERED  SECOND_DOSE_ADMINISTERED  ONLY_FIRST_DOSE
# 0                296140652                  56636504        239504148
# 1                296140652                  56636504        239504148
# ...

# %%
df_cmbnd1_2_inner_temp.set_index('Sno', inplace = True)
df_cmbnd1_2_inner_temp.head()
# Out:
#            Date     Time   State ConfirmedIndianNational  \
# Sno
# 1    2020-01-30  6:00 PM  Kerala                       1
# 2    2020-01-31  6:00 PM  Kerala                       1
# 3    2020-02-01  6:00 PM  Kerala                       2
# 4    2020-02-02  6:00 PM  Kerala                       3
# 5    2020-02-03  6:00 PM  Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed   STATE  \
# Sno
# 1                          0      0       0          1  Kerala
# 2                          0      0       0          1  Kerala
# 3                          0      0       0          2  Kerala
# 4                          0      0       0          3  Kerala
# 5                          0      0       0          3  Kerala
#
#      FIRST_DOSE_ADMINISTERED  SECOND_DOSE_ADMINISTERED  ONLY_FIRST_DOSE
# Sno
# 1                  296140652                  56636504        239504148
# 2                  296140652                  56636504        239504148
# ...

# %%
df_cmbnd1_2_inner_temp[df_cmbnd1_2_inner_temp['State'] != df_cmbnd1_2_inner_temp['STATE']]
# Out:
# Empty DataFrame
# Columns: [Date, Time, State, ConfirmedIndianNational, ConfirmedForeignNational, Cured, Deaths, Confirmed, STATE, FIRST_DOSE_ADMINISTERED, SECOND_DOSE_ADMINISTERED, ONLY_FIRST_DOSE]
# Index: []

# %%
pd.set_option('display.max_colwidth',None)

# %%
df_cmbnd1_2_inner = df_cmbnd1_2_inner_temp.drop('STATE',axis = 1, inplace = False)
df_cmbnd1_2_inner.head()
# Out:
#            Date     Time   State ConfirmedIndianNational  \
# Sno
# 1    2020-01-30  6:00 PM  Kerala                       1
# 2    2020-01-31  6:00 PM  Kerala                       1
# 3    2020-02-01  6:00 PM  Kerala                       2
# 4    2020-02-02  6:00 PM  Kerala                       3
# 5    2020-02-03  6:00 PM  Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed  \
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3
#
#      FIRST_DOSE_ADMINISTERED  SECOND_DOSE_ADMINISTERED  ONLY_FIRST_DOSE
# Sno
# 1                  296140652                  56636504        239504148
# 2                  296140652                  56636504        239504148
# ...

# %%
df_cmbnd1_2_inner.to_excel(output_path+'/df_cmbnd1_2_inner.xlsx')
